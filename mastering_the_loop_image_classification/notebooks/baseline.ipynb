# %% [markdown]
# # Analysis of Baseline model
#
# load data

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df = pd.read_csv(r'C:\data\retina_dataset\model\models_erebor\002\metrics.csv')
df['epoch'] = range(len(df))

# %%
# sns.set_theme()
# sns.lineplot(data=df, x="train_loss", y='epoch')

f, ax = plt.subplots(1, 1)
# x_col='date'
# y_col = 'count'

ax.plot(df['epoch'], df['train_loss'], color="blue", label="Train", linestyle="-")
ax.plot(df['epoch'], df["val_loss"], color="red", label="Val", linestyle="-")
# ax.plot_date(df3.date, df3["count"], color="green", label="C", linestyle="-")

ax.legend()
