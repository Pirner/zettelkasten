# %% [markdown]
# # Analysis of Baseline model
#
# load data

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df = pd.read_csv(r'C:\data\retina_dataset\model\000\metrics.csv')
df['epoch'] = range(len(df))

# %%
# sns.set_theme()
# sns.lineplot(data=df, x="train_loss", y='epoch')

f, ax = plt.subplots(1, 1)
# x_col='date'
# y_col = 'count'

ax.plot_date(df['epoch'], df['train_loss'], color="blue", label="Train", linestyle="-")
ax.plot_date(df['epoch'], df["val_loss"], color="red", label="Val", linestyle="-")
# ax.plot_date(df3.date, df3["count"], color="green", label="C", linestyle="-")

ax.legend()
# Out:
# C:\Users\steph\AppData\Local\Temp\ipykernel_30032\1565571904.py:8: MatplotlibDeprecationWarning: The plot_date function was deprecated in Matplotlib 3.9 and will be removed in 3.11. Use plot instead.
#   ax.plot_date(df['epoch'], df['train_loss'], color="blue", label="Train", linestyle="-")
